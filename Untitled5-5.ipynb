# %%
import pandas as pd

df = pd.read_csv('Chicago_Crimes_2012_to_2017.csv')

df.head()
# Out:
#    Unnamed: 0        ID Case Number                    Date
# 0           3  10508693    HZ250496  05/03/2016 11:40:00 PM  \
# 1          89  10508695    HZ250409  05/03/2016 09:40:00 PM
# 2         197  10508697    HZ250503  05/03/2016 11:31:00 PM
# 3         673  10508698    HZ250424  05/03/2016 10:10:00 PM
# 4         911  10508699    HZ250455  05/03/2016 10:00:00 PM
#
#                  Block  IUCR            Primary Type              Description
# 0   013XX S SAWYER AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE  \
# 1   061XX S DREXEL AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 2  053XX W CHICAGO AVE  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 3    049XX W FULTON ST  0460                 BATTERY                   SIMPLE
# 4    003XX N LOTUS AVE  0820                   THEFT           $500 AND UNDER
#
#   Location Description  Arrest  ...  Ward  Community Area  FBI Code
# ...

# %%
missing_values = df.isnull().sum()

missing_values
# Out:
# Unnamed: 0                  0
# ID                          0
# Case Number                 1
# Date                        0
# Block                       0
# IUCR                        0
# Primary Type                0
# Description                 0
# Location Description     1658
# Arrest                      0
# Domestic                    0
# Beat                        0
# District                    1
# Ward                       14
# Community Area             40
# FBI Code                    0
# X Coordinate            37083
# Y Coordinate            37083
# Year                        0
# Updated On                  0
# Latitude                37083
# Longitude               37083
# Location                37083
# dtype: int64

# %%
df_cleaned = df.dropna()

rows_after_cleaning = df_cleaned.shape[0]

rows_dropped = df.shape[0] - rows_after_cleaning
rows_dropped, rows_after_cleaning
# Out:
# (38349, 1418365)

# %%
from sklearn.model_selection import train_test_split

features = ['Latitude', 'Longitude', 'District', 'Ward', 'Domestic', 'Distance_from_center']
target = 'Arrest' 

X = df_cleaned[features]
y = df_cleaned[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train.shape, X_test.shape
# Out:
# ((992855, 6), (425510, 6))

# %%
X.head()
# Out:
#     Latitude  Longitude  District  Ward  Domestic  Distance_from_center
# 0  41.864073 -87.706819      10.0  24.0      True              0.078285
# 1  41.782922 -87.604363       3.0  20.0      True              0.098519
# 2  41.894908 -87.758372      15.0  37.0     False              0.129666
# 3  41.885687 -87.749516      15.0  28.0     False              0.119956
# 4  41.886297 -87.761751      15.0  28.0      True              0.132205

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

le_district = LabelEncoder()
le_ward = LabelEncoder()
le_arrest = LabelEncoder()
le_domestic = LabelEncoder()

X_train['District'] = le_district.fit_transform(X_train['District'])
X_train['Ward'] = le_ward.fit_transform(X_train['Ward'])
X_train['Domestic'] = le_domestic.fit_transform(X_train['Domestic'])

X_test['District'] = le_district.transform(X_test['District'])
X_test['Ward'] = le_ward.transform(X_test['Ward'])
X_test['Domestic'] = le_domestic.transform(X_test['Domestic'])

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

clf = DecisionTreeClassifier(max_depth=10, random_state=42)
clf.fit(X_train_scaled, y_train)

y_pred = clf.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

accuracy, classification_rep
# Out:
# (0.7482197833188409,
#  '              precision    recall  f1-score   support\n\n       False       0.76      0.95      0.85    314397\n        True       0.56      0.17      0.26    111113\n\n    accuracy                           0.75    425510\n   macro avg       0.66      0.56      0.55    425510\nweighted avg       0.71      0.75      0.69    425510\n')

# %%
import numpy as np

center_lat = 41.8781
center_long = -87.6298

df_cleaned['Distance_from_center'] = np.sqrt((df_cleaned['Latitude'] - center_lat)**2 + 
                                             (df_cleaned['Longitude'] - center_long)**2)

df_cleaned[['Latitude', 'Longitude', 'Distance_from_center']].head()
# Out:
# /tmp/ipykernel_347/3045006099.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Distance_from_center'] = np.sqrt((df_cleaned['Latitude'] - center_lat)**2 +
#     Latitude  Longitude  Distance_from_center
# 0  41.864073 -87.706819              0.078285
# 1  41.782922 -87.604363              0.098519
# 2  41.894908 -87.758372              0.129666
# 3  41.885687 -87.749516              0.119956
# 4  41.886297 -87.761751              0.132205

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0        ID Case Number                    Date
# 0           3  10508693    HZ250496  05/03/2016 11:40:00 PM  \
# 1          89  10508695    HZ250409  05/03/2016 09:40:00 PM
# 2         197  10508697    HZ250503  05/03/2016 11:31:00 PM
# 3         673  10508698    HZ250424  05/03/2016 10:10:00 PM
# 4         911  10508699    HZ250455  05/03/2016 10:00:00 PM
#
#                  Block  IUCR            Primary Type              Description
# 0   013XX S SAWYER AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE  \
# 1   061XX S DREXEL AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 2  053XX W CHICAGO AVE  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 3    049XX W FULTON ST  0460                 BATTERY                   SIMPLE
# 4    003XX N LOTUS AVE  0820                   THEFT           $500 AND UNDER
#
#   Location Description  Arrest  ...  Community Area  FBI Code  X Coordinate
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

clf_rf = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
clf_rf.fit(X_train, y_train)

y_pred_rf = clf_rf.predict(X_test)

# %%
import matplotlib.pyplot as plt

# Assuming y_test are the true labels and y_pred are the predicted labels
plt.figure(figsize=(12, 12))
plt.scatter(X_test['Longitude'], X_test['Latitude'], c=y_pred, alpha=0.5, 
            cmap='viridis', label='Predicted Labels')
plt.scatter(X_test['Longitude'], X_test['Latitude'], c=y_test, alpha=0.5, 
            cmap='viridis', marker='x', label='True Labels')
plt.title('True vs. Predicted Arrests')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming y_test are the true labels and y_pred are the predicted labels
plt.figure(figsize=(12, 12))
plt.scatter(X_test['Longitude'], X_test['Latitude'], c=y_pred, alpha=0.5, 
            cmap='viridis', label='Predicted Labels')
plt.scatter(X_test['Longitude'], X_test['Latitude'], c=y_test, alpha=0.5, 
            cmap='viridis', marker='x', label='True Labels')

# Set axis limits
plt.xlim([-88, -87.3])
plt.ylim([41.3, 42.5])

plt.title('True vs. Predicted Arrests in a Specific Region')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred)

conf_matrix, accuracy
# Out:
# (array([[298252,  16145],
#         [ 91262,  19851]]),
#  0.7475805503983455)

# %%
# Calculate the count and percentage of each class in the 'Arrest' column
arrest_counts = df_cleaned['Arrest'].value_counts()
arrest_percentages = df_cleaned['Arrest'].value_counts(normalize=True) * 100

arrest_counts, arrest_percentages
# Out:
# (Arrest
#  False    1047308
#  True      371057
#  Name: count, dtype: int64,
#  Arrest
#  False    73.839103
#  True     26.160897
#  Name: proportion, dtype: float64)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %%
clf.fit(X_resampled, y_resampled)
y_pred_resampled = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred_resampled))
print(classification_report(y_test, y_pred_resampled))
# Out:
# Accuracy: 0.630466969048906
#               precision    recall  f1-score   support
#
#        False       0.81      0.65      0.72    314397
#         True       0.37      0.58      0.45    111113
#
#     accuracy                           0.63    425510
#    macro avg       0.59      0.62      0.59    425510
# weighted avg       0.70      0.63      0.65    425510

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5, scoring='f1', n_jobs=-1)

grid_search.fit(X_resampled, y_resampled)

best_params = grid_search.best_params_
best_params
# Out:
# /opt/conda/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 15
#      12 grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5, scoring='f1', n_jobs=-1)
#      14 # Perform the grid search on the resampled data
# ---> 15 grid_search.fit(X_resampled, y_resampled)
#      17 # Get the best hyperparameters
#      18 best_params = grid_search.best_params_
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
# ...

# %%
best_rf_model = RandomForestClassifier(random_state=42, **best_params)
best_rf_model.fit(X_resampled, y_resampled)

# %%
y_pred_best_rf = best_rf_model.predict(X_test)

from sklearn.metrics import classification_report, accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred_best_rf))
print(classification_report(y_test, y_pred_best_rf))

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_dist = {
    'n_estimators': randint(100, 500),
    'max_depth': [None] + list(np.arange(10, 31, 5)),
    'min_samples_split': randint(2, 11),
    'min_samples_leaf': randint(1, 5)
}

random_search = RandomizedSearchCV(RandomForestClassifier(random_state=42), param_distributions=param_dist,
                                   n_iter=10, cv=5, scoring='f1', n_jobs=-1, random_state=42)

random_search.fit(X_resampled, y_resampled)

best_params_random = random_search.best_params_
best_params_random
# Out:
# /opt/conda/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 17
#      13 random_search = RandomizedSearchCV(RandomForestClassifier(random_state=42), param_distributions=param_dist,
#      14                                    n_iter=10, cv=5, scoring='f1', n_jobs=-1, random_state=42)
#      16 # Perform the randomized search on the resampled data
# ---> 17 random_search.fit(X_resampled, y_resampled)
#      19 # Get the best hyperparameters
#      20 best_params_random = random_search.best_params_
#
# ...

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(random_state=42)

xgb_model.fit(X_resampled, y_resampled)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_xgb = xgb_model.predict(X_test)

from sklearn.metrics import classification_report, accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
# Out:
# Accuracy: 0.6567413221780922
#               precision    recall  f1-score   support
#
#        False       0.82      0.68      0.75    314397
#         True       0.40      0.59      0.47    111113
#
#     accuracy                           0.66    425510
#    macro avg       0.61      0.64      0.61    425510
# weighted avg       0.71      0.66      0.67    425510

# %%
from sklearn.utils import resample

# Specify the desired ratio (e.g., 1:1)
desired_ratio = 1.0

# Calculate the number of majority class samples to keep
minority_class_count = sum(y_train)
majority_class_count = len(y_train) - minority_class_count
undersample_ratio = minority_class_count / majority_class_count

# Perform random undersampling
if undersample_ratio < desired_ratio:
    # If the current ratio is less than desired, perform undersampling
    majority_class_indices = y_train[y_train == 0].index
    undersampled_indices = resample(majority_class_indices, n_samples=int(majority_class_count * desired_ratio),
                                    random_state=42)
    X_undersampled = pd.concat([X_train.loc[undersampled_indices], X_train.loc[y_train == 1]])
    y_undersampled = pd.concat([y_train.loc[undersampled_indices], y_train.loc[y_train == 1]])
else:
    # If the current ratio is equal to or greater than desired, no undersampling is needed
    X_undersampled = X_train
    y_undersampled = y_train

# %%
from sklearn.ensemble import RandomForestClassifier

# Create the Random Forest classifier with class weighting
rf_model_weighted = RandomForestClassifier(class_weight='balanced', random_state=42)

# Train the model on the undersampled data
rf_model_weighted.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
y_pred_weighted = rf_model_weighted.predict(X_test)

from sklearn.metrics import classification_report, accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred_weighted))
print(classification_report(y_test, y_pred_weighted))
# Out:
# Accuracy: 0.6920683415195883
#               precision    recall  f1-score   support
#
#        False       0.82      0.75      0.78    314397
#         True       0.43      0.54      0.48    111113
#
#     accuracy                           0.69    425510
#    macro avg       0.63      0.64      0.63    425510
# weighted avg       0.72      0.69      0.70    425510

# %%
original_class_distribution = y_train.value_counts(normalize=True) * 100

resampled_class_distribution = y_resampled.value_counts(normalize=True) * 100

print("Class Distribution Before Resampling:")
print(original_class_distribution)

print("\nClass Distribution After Resampling:")
print(resampled_class_distribution)
# Out:
# Class Distribution Before Resampling:
# Arrest
# False    73.818533
# True     26.181467
# Name: proportion, dtype: float64
#
# Class Distribution After Resampling:
# Arrest
# False    50.0
# True     50.0
# Name: proportion, dtype: float64

# %%
X_train.head()
# Out:
#           Latitude  Longitude  District  Ward  Domestic
# 917966   41.911449 -87.746739        22    36         0
# 1355179  41.658191 -87.545899         3     9         0
# 81047    41.888326 -87.755357        14    27         0
# 848768   41.967904 -87.667295        18    46         0
# 127981   41.752551 -87.602787         5     5         1

# %%
df.head()
# Out:
#    Unnamed: 0        ID Case Number                    Date
# 0           3  10508693    HZ250496  05/03/2016 11:40:00 PM  \
# 1          89  10508695    HZ250409  05/03/2016 09:40:00 PM
# 2         197  10508697    HZ250503  05/03/2016 11:31:00 PM
# 3         673  10508698    HZ250424  05/03/2016 10:10:00 PM
# 4         911  10508699    HZ250455  05/03/2016 10:00:00 PM
#
#                  Block  IUCR            Primary Type              Description
# 0   013XX S SAWYER AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE  \
# 1   061XX S DREXEL AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 2  053XX W CHICAGO AVE  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 3    049XX W FULTON ST  0460                 BATTERY                   SIMPLE
# 4    003XX N LOTUS AVE  0820                   THEFT           $500 AND UNDER
#
#   Location Description  Arrest  ...  Ward  Community Area  FBI Code
# ...

# %%
# Check the column names in your DataFrame
column_names = df.columns
column_names
# Out:
# Index(['Unnamed: 0', 'ID', 'Case Number', 'Date', 'Block', 'IUCR',
#        'Primary Type', 'Description', 'Location Description', 'Arrest',
#        'Domestic', 'Beat', 'District', 'Ward', 'Community Area', 'FBI Code',
#        'X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
columns_to_encode = ["Primary Type", "Location Description"]

df_encoded = pd.get_dummies(df, columns=columns_to_encode, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

features = ['Latitude', 'Longitude', 'District', 'Ward', 'Domestic', 'Primary Type', 'Location Description', 'Distance_from_center']
target = 'Arrest'  # Using "Arrest" as the target for classification

X = df_cleaned[features]
y = df_cleaned[target]

# Specify the columns to one-hot encode
columns_to_encode = ["Primary Type", "Location Description"]

# Apply one-hot encoding to the specified columns
X_encoded = pd.get_dummies(X, columns=columns_to_encode, drop_first=True)

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.3, random_state=42)

# Checking the dimensions of the training and test sets
print("Training set dimensions:", X_train.shape)
print("Test set dimensions:", X_test.shape)
# Out:
# Training set dimensions: (992855, 177)
# Test set dimensions: (425510, 177)

# %%
X_train.head()
# Out:
#           Latitude  Longitude  District  Ward  Domestic  Distance_from_center
# 917966   41.911449 -87.746739      25.0  37.0     False              0.121601  \
# 1355179  41.658191 -87.545899       4.0  10.0     False              0.235371
# 81047    41.888326 -87.755357      15.0  28.0     False              0.125973
# 848768   41.967904 -87.667295      19.0  47.0     False              0.097317
# 127981   41.752551 -87.602787       6.0   6.0      True              0.128422
#
#          Primary Type_ASSAULT  Primary Type_BATTERY  Primary Type_BURGLARY
# 917966                  False                 False                  False  \
# 1355179                 False                 False                  False
# 81047                   False                 False                  False
# 848768                  False                 False                  False
# 127981                  False                 False                  False
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

rf_model = RandomForestClassifier(random_state=42)

rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.8591102441775752
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.89      0.93      0.91    314397
#         True       0.77      0.66      0.71    111113
#
#     accuracy                           0.86    425510
#    macro avg       0.83      0.80      0.81    425510
# weighted avg       0.85      0.86      0.86    425510

# %%
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# Step 2: Train and evaluate the model on the original high-dimensional data
# Create and train a Random Forest classifier on the original data
rf_model_original = RandomForestClassifier(random_state=42)
rf_model_original.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred_original = rf_model_original.predict(X_test)
accuracy_original = accuracy_score(y_test, y_pred_original)
report_original = classification_report(y_test, y_pred_original)

# Step 3: Apply dimensionality reduction (e.g., PCA)
n_components = 50  # Choose the number of components for PCA
pca = PCA(n_components=n_components)

X_train_reduced = pca.fit_transform(X_train)
X_test_reduced = pca.transform(X_test)

# Step 4: Train and evaluate the model on the reduced-dimension data
# Create and train a Random Forest classifier on the reduced-dimension data
rf_model_reduced = RandomForestClassifier(random_state=42)
rf_model_reduced.fit(X_train_reduced, y_train)

# Make predictions and evaluate the model
y_pred_reduced = rf_model_reduced.predict(X_test_reduced)
accuracy_reduced = accuracy_score(y_test, y_pred_reduced)
report_reduced = classification_report(y_test, y_pred_reduced)

# Compare performance
print("Performance on Original Data:")
print("Accuracy:", accuracy_original)
print("Classification Report:\n", report_original)

print("\nPerformance on Reduced-Dimension Data:")
print("Accuracy:", accuracy_reduced)
print("Classification Report:\n", report_reduced)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 30
#      27 # Step 4: Train and evaluate the model on the reduced-dimension data
#      28 # Create and train a Random Forest classifier on the reduced-dimension data
#      29 rf_model_reduced = RandomForestClassifier(random_state=42)
# ---> 30 rf_model_reduced.fit(X_train_reduced, y_train)
#      32 # Make predictions and evaluate the model
#      33 y_pred_reduced = rf_model_reduced.predict(X_test_reduced)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
# ...

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
from sklearn.model_selection import train_test_split


n_estimators_values = [50, 100, 200]  

for n_estimators in n_estimators_values:
    xgb_model_original = XGBClassifier(n_estimators=n_estimators, random_state=42)
    xgb_model_original.fit(X_train, y_train)

    y_pred_original = xgb_model_original.predict(X_test)
    accuracy_original = accuracy_score(y_test, y_pred_original)
    report_original = classification_report(y_test, y_pred_original)

    print(f"Performance with {n_estimators} boosting rounds:")
    print("Accuracy on Original Data:", accuracy_original)
    print("Classification Report on Original Data:\n", report_original)
    print("-" * 50)
# Out:
# Performance with 50 boosting rounds:
# Accuracy on Original Data: 0.8785715964372165
# Classification Report on Original Data:
#                precision    recall  f1-score   support
#
#        False       0.87      0.98      0.92    314397
#         True       0.90      0.61      0.72    111113
#
#     accuracy                           0.88    425510
#    macro avg       0.89      0.79      0.82    425510
# weighted avg       0.88      0.88      0.87    425510
#
# --------------------------------------------------
# Performance with 100 boosting rounds:
# Accuracy on Original Data: 0.879584498601678
# Classification Report on Original Data:
#                precision    recall  f1-score   support
#
#        False       0.88      0.97      0.92    314397
#         True       0.89      0.61      0.73    111113
#
#     accuracy                           0.88    425510
#    macro avg       0.88      0.79      0.82    425510
# weighted avg       0.88      0.88      0.87    425510
#
# ...

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
import numpy as np

xgb_model = XGBClassifier(n_estimators=100, max_depth=3, random_state=42)  # Replace with your desired hyperparameters

k = 5 
scores = cross_val_score(xgb_model, X_train, y_train, cv=k, scoring='accuracy')

mean_accuracy = np.mean(scores)
std_accuracy = np.std(scores)

print(f"Mean Accuracy: {mean_accuracy:.4f}")
print(f"Standard Deviation: {std_accuracy:.4f}")
# Out:
# Mean Accuracy: 0.8754
# Standard Deviation: 0.0008

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Define candidate models and their respective hyperparameter grids
models = [
    ('RandomForest', RandomForestClassifier(), {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20]}),
    ('XGBoost', XGBClassifier(), {'n_estimators': [50, 100, 200], 'max_depth': [3, 5, 7], 'learning_rate': [0.1, 0.01]})
]

# Perform grid search with cross-validation for each model
best_model = None
best_score = 0

for model_name, model, param_grid in models:
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)
    
    # Get the best hyperparameters and CV score for this model
    best_params = grid_search.best_params_
    cv_score = grid_search.best_score_
    
    print(f"Model: {model_name}")
    print(f"Best Hyperparameters: {best_params}")
    print(f"CV Score (Accuracy): {cv_score:.4f}")
    
    # Check if this model outperforms the current best model
    if cv_score > best_score:
        best_score = cv_score
        best_model = grid_search.best_estimator_

# Train the best model on the full training dataset
best_model.fit(X_train, y_train)

# Evaluate the best model on a holdout test set
test_score = best_model.score(X_test, y_test)
print(f"Test Score (Accuracy): {test_score:.4f}")
# Out:
# Model: RandomForest
# Best Hyperparameters: {'max_depth': None, 'n_estimators': 50}
# CV Score (Accuracy): 0.9500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 17
#      15 for model_name, model, param_grid in models:
#      16     grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
# ---> 17     grid_search.fit(X_train, y_train)
#      19     # Get the best hyperparameters and CV score for this model
#      20     best_params = grid_search.best_params_
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
# ...

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# Define a parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    # Add other hyperparameters you want to tune
}

# Create an XGBoost classifier
xgb_model = XGBClassifier(random_state=42)

# Perform grid search cross-validation
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)

# Print the best hyperparameters found
print("Best Hyperparameters:", grid_search.best_params_)

# Use the best model
best_xgb_model = grid_search.best_estimator_
# Out:
# Epoch 100/100 - Accuracy: 1.0000
# Training completed.

# %%
import matplotlib.pyplot as plt

n_estimators_values = [50, 100, 200]
accuracies = []  # To store accuracy values for each n_estimators

for n_estimators in n_estimators_values:
    xgb_model_original = XGBClassifier(n_estimators=n_estimators, random_state=42)
    xgb_model_original.fit(X_train, y_train)

    y_pred_original = xgb_model_original.predict(X_test)
    accuracy_original = accuracy_score(y_test, y_pred_original)
    report_original = classification_report(y_test, y_pred_original)

    accuracies.append(accuracy_original)

    print(f"Performance with {n_estimators} boosting rounds:")
    print("Accuracy on Original Data:", accuracy_original)
    print("Classification Report on Original Data:\n", report_original)
    print("-" * 50)

# Plot the accuracy values against the number of boosting rounds
plt.figure(figsize=(10, 6))
plt.plot(n_estimators_values, accuracies, marker='o', linestyle='-', color='b', label='Model Accuracy')
plt.xlabel('Number of Boosting Rounds (n_estimators)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Boosting Rounds')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Performance with 50 boosting rounds:
# Accuracy on Original Data: 0.8785715964372165
# Classification Report on Original Data:
#                precision    recall  f1-score   support
#
#        False       0.87      0.98      0.92    314397
#         True       0.90      0.61      0.72    111113
#
#     accuracy                           0.88    425510
#    macro avg       0.89      0.79      0.82    425510
# weighted avg       0.88      0.88      0.87    425510
#
# --------------------------------------------------
# Performance with 100 boosting rounds:
# Accuracy on Original Data: 0.879584498601678
# Classification Report on Original Data:
#                precision    recall  f1-score   support
#
#        False       0.88      0.97      0.92    314397
#         True       0.89      0.61      0.73    111113
#
#     accuracy                           0.88    425510
#    macro avg       0.88      0.79      0.82    425510
# weighted avg       0.88      0.88      0.87    425510
#
# ...
